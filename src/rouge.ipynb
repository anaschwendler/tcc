# %%
import numpy as np
uni_ref=ref_texts['A'].lower().split()
uni_sum=summary_text.lower().split()

p= len(np.intersect1d(uni_ref,uni_sum))/float(len(uni_sum))
p
# Out:
# 0.297029702970297

# %%
from pyrouge import Rouge155
from __future__ import print_function
# %matplotlib inline

from __future__ import print_function
import sys

import matplotlib.pyplot as plt
import nltk
nltk.sent_tokenizer=nltk.data.load('tokenizers/punkt/portuguese.pickle')

def remove_extra_info_from_rouge(d):
    saida ={}
    for key, value in d.iteritems():
        if ("_cb" not in key) and ("_ce" not in key):
            saida[key]=value
    return saida

ref_texts = { 'A': open('experimentos/01/C1_extrato_humano.txt', 'r').read().decode('utf-8') }
summary_text = open('experimentos/01/C1_extrato_wives.txt', 'r').read().decode('utf-8')

rouge = Rouge155(rouge_home='/home/ana/anaconda2/lib/python2.7/site-packages/pyrouge/ROUGE-1.5.5')
score = rouge.score_summary(summary_text, ref_texts)
print(remove_extra_info_from_rouge(score))

import matplotlib.pyplot as plt

D = remove_extra_info_from_rouge(score)

plt.bar(range(len(D)), D.values(), align='center')
locs, label = plt.xticks(range(len(D)), D.keys())
plt.setp(label, rotation=90)

plt.show()

ref_texts = { 'A': open('output/experiments/C1_Mundo_AviaoCongo/extrato_humano.txt', 'r').read().decode('utf-8') }
summary_text = open('output/experiments/C1_Mundo_AviaoCongo/concept_summ.txt', 'r').read().decode('utf-8')

rouge = Rouge155(rouge_home='/home/ana/anaconda2/lib/python2.7/site-packages/pyrouge/ROUGE-1.5.5')
score = rouge.score_summary(summary_text, ref_texts)
print(remove_extra_info_from_rouge(score))

import matplotlib.pyplot as plt

D = remove_extra_info_from_rouge(score)

plt.bar(range(len(D)), D.values(), align='center')
locs, label = plt.xticks(range(len(D)), D.keys())
plt.setp(label, rotation=90)

plt.show()
# Out:
# {'rouge_su4_precision': 0.95826, 'rouge_1_precision': 0.99744, 'rouge_4_recall': 0.21573, 'rouge_1_f_score': 0.6315, 'rouge_su4_f_score': 0.60517, 'rouge_3_recall': 0.26667, 'rouge_4_precision': 0.4677, 'rouge_4_f_score': 0.29527, 'rouge_2_recall': 0.3912, 'rouge_3_f_score': 0.36482, 'rouge_3_precision': 0.57732, 'rouge_2_precision': 0.84576, 'rouge_2_f_score': 0.53496, 'rouge_1_recall': 0.462, 'rouge_su4_recall': 0.44222}
# {'rouge_su4_precision': 0.95697, 'rouge_1_precision': 0.99744, 'rouge_4_recall': 0.21216, 'rouge_1_f_score': 0.6315, 'rouge_su4_f_score': 0.60435, 'rouge_3_recall': 0.26667, 'rouge_4_precision': 0.45995, 'rouge_4_f_score': 0.29038, 'rouge_2_recall': 0.3912, 'rouge_3_f_score': 0.36482, 'rouge_3_precision': 0.57732, 'rouge_2_precision': 0.84576, 'rouge_2_f_score': 0.53496, 'rouge_1_recall': 0.462, 'rouge_su4_recall': 0.44162}

# %%
from pyrouge import Rouge155
from __future__ import print_function
# %matplotlib inline

from __future__ import print_function
import sys
import os, fnmatch

import matplotlib.pyplot as plt
import nltk
nltk.sent_tokenizer=nltk.data.load('tokenizers/punkt/portuguese.pickle')

def remove_extra_info_from_rouge(d):
    saida ={}
    for key, value in d.iteritems():
        if ("_cb" not in key) and ("_ce" not in key):
            saida[key]=value
    return saida

rootdir = 'output'

# for subdirs, dirs, files in os.walk(rootdir):
#   for dir in dirs:
#     for file in os.listdir(os.path.join(subdirs, dir)):
#       if fnmatch.fnmatch(file, '*original.txt'):
#         ref_texts = { 'A': open(os.path.join(subdirs, dir, 'extrato_humano.txt'), 'r').read().decode('utf-8') }
#         summary_text = open(os.path.join(subdirs, dir, 'sumario_automatico_CSTSumm.txt'), 'r').read().decode('latin-1')
#         rouge = Rouge155(rouge_home='/home/ana/anaconda2/lib/python2.7/site-packages/pyrouge/ROUGE-1.5.5')
#         score = rouge.score_summary(summary_text, ref_texts)
#         f = open(os.path.join(subdirs, dir, 'rouge_CSTSUmm.txt'), 'w+')
#         f.write(str(remove_extra_info_from_rouge(score)))

# %%
# for subdirs, dirs, files in os.walk(rootdir):
#   for dir in dirs:
#     for file in os.listdir(os.path.join(subdirs, dir)):
#       if fnmatch.fnmatch(file, '*original.txt'):
#         ref_texts = { 'A': open(os.path.join(subdirs, dir, 'extrato_humano.txt'), 'r').read().decode('utf-8') }
#         summary_text = open(os.path.join(subdirs, dir, 'concept_summ.txt'), 'r').read().decode('latin-1')
#         rouge = Rouge155(rouge_home='/home/ana/anaconda2/lib/python2.7/site-packages/pyrouge/ROUGE-1.5.5')
#         score = rouge.score_summary(summary_text, ref_texts)
#         f = open(os.path.join(subdirs, dir, 'rouge_concept.txt'), 'w+')
#         f.write(str(remove_extra_info_from_rouge(score)))

# %%
# for subdirs, dirs, files in os.walk(rootdir):
#   for dir in dirs:
#     for file in os.listdir(os.path.join(subdirs, dir)):
#       if fnmatch.fnmatch(file, '*original.txt'):
#         ref_texts = { 'A': open(os.path.join(subdirs, dir, 'extrato_humano.txt'), 'r').read().decode('utf-8') }
#         summary_text = open(os.path.join(subdirs, dir, 'lexrank_summ.txt'), 'r').read().decode('latin-1')
#         rouge = Rouge155(rouge_home='/home/ana/anaconda2/lib/python2.7/site-packages/pyrouge/ROUGE-1.5.5')
#         score = rouge.score_summary(summary_text, ref_texts)
#         f = open(os.path.join(subdirs, dir, 'rouge_lexrank.txt'), 'w+')
#         f.write(str(remove_extra_info_from_rouge(score)))
